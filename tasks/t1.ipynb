# %% [markdown]
# Read a data set and count the null values and also see the structure and info of the data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
pp=pd.read_csv("weatherHistory.csv",na_values="?",skipinitialspace=True)
# print(pp.head())
print(pp.shape)
# print(pp.info())
# pp.isnull().sum()/96455 *100
print(pp.isnull().sum())
pp.duplicated().sum()
# Out:
# (96453, 12)
# Formatted Date                0
# Summary                       0
# Precip Type                 517
# Temperature (C)               0
# Apparent Temperature (C)      0
# Humidity                      1
# Wind Speed (km/h)             0
# Wind Bearing (degrees)        0
# Visibility (km)               0
# Loud Cover                    0
# Pressure (millibars)          0
# Daily Summary                 0
# dtype: int64
# C:\Users\sakib\AppData\Local\Temp\ipykernel_7204\163465562.py:1: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   pp=pd.read_csv("weatherHistory.csv",na_values="?",skipinitialspace=True)
# np.int64(24)
